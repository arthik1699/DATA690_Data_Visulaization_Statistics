# %% [markdown]
# <a href="https://colab.research.google.com/github/arthik1699/DATA690_Data_Visulaization_Statistics/blob/main/Assignment_07/Assignment07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data690 - Data Visualization & Statistics
# ## Assignment- 7
#
# * Name - Arthi Komma
# * Campus id - GF89659

# %% [markdown]
#  ## To explore the dataset and produce data visualizations using the following requirements:
#
# -  Must use Plotly/Plotly Express.

# %%
import pandas as pd                            # importing pandas module
import plotly.express as px                    # importing plotly.express module

# %%
# Reading the csv file from the provided link
df = pd.read_csv("https://raw.githubusercontent.com/wcj365/python-stats-dataviz/master/assignments/assignment_07_world_dev/world_devlopment_indicator.csv")

df.shape         # finding the shape of the data frame
# Out:
# (34954, 9)

# %%
df.sample(10)     # Fecting the sample data from the data frame
# Out:
#        Unnamed: 0  Year         value          indicator Country Code  \
# 34099       34099  2005  2.768459e+07        SP.POP.TOTL          UGA
# 16295       16295  1989  4.603800e+01     SP.DYN.LE00.IN          MWI
# 29867       29867  1989  1.280595e+07        SP.POP.TOTL          MOZ
# 22241       22241  1976  7.565525e+06        SP.POP.TOTL          AUT
# 30712       30712  1966  6.420070e+05        SP.POP.TOTL          OMN
# 9907         9907  2010  7.582300e+01     SP.DYN.LE00.IN          ATG
# 2926         2926  2016  4.681175e+03  NY.GDP.PCAP.PP.CD          KGZ
# 19001       19001  2001  4.036900e+01     SP.DYN.LE00.IN          SLE
# 28871       28871  1985  1.006349e+07        SP.POP.TOTL          MDG
# 4299         4299  1992  1.317508e+04  NY.GDP.PCAP.PP.CD          PRT
#
#               Country Name                      Region         Income Group  \
# 34099               Uganda         Sub-Saharan Africa            Low income
# 16295               Malawi         Sub-Saharan Africa            Low income
# 29867           Mozambique         Sub-Saharan Africa            Low income
# 22241              Austria       Europe & Central Asia          High income
# 30712                 Oman  Middle East & North Africa          High income
# 9907   Antigua and Barbuda  Latin America & Caribbean           High income
# 2926       Kyrgyz Republic       Europe & Central Asia  Lower middle income
# 19001         Sierra Leone         Sub-Saharan Africa            Low income
# 28871           Madagascar         Sub-Saharan Africa            Low income
# 4299              Portugal       Europe & Central Asia          High income
#
#          Lending Type
# 34099             IDA
# 16295             IDA
# 29867             IDA
# 22241  Not classified
# 30712  Not classified
# 9907             IBRD
# 2926              IDA
# 19001             IDA
# 28871             IDA
# 4299   Not classified

# %% [markdown]
# ## Picking a few countries of our interest and comparing them to see how they differ in the indicator
# - Comparing one year (pick the latest year) using bar chart, pie chart
# - Comparing all years using line chart

# %% [markdown]
# #### Manipulating the data frame to get the desired set of data to plot bar and pie chart

# %%
my_countries = ["ETH", "IND", "PAK"]

df2 = df[df["Country Code"].isin(my_countries)]

df2.shape
# Out:
# (525, 9)

# %%
df2["Country Name"].unique()
# Out:
# array(['Ethiopia', 'India', 'Pakistan'], dtype=object)

# %%
df2.head()
# Out:
#       Unnamed: 0  Year       value          indicator Country Code  \
# 1786        1786  1990  414.566679  NY.GDP.PCAP.PP.CD          ETH
# 1787        1787  1991  384.180428  NY.GDP.PCAP.PP.CD          ETH
# 1788        1788  1992  346.202029  NY.GDP.PCAP.PP.CD          ETH
# 1789        1789  1993  386.903099  NY.GDP.PCAP.PP.CD          ETH
# 1790        1790  1994  393.837942  NY.GDP.PCAP.PP.CD          ETH
#
#      Country Name               Region Income Group Lending Type
# 1786     Ethiopia  Sub-Saharan Africa    Low income          IDA
# 1787     Ethiopia  Sub-Saharan Africa    Low income          IDA
# 1788     Ethiopia  Sub-Saharan Africa    Low income          IDA
# 1789     Ethiopia  Sub-Saharan Africa    Low income          IDA
# 1790     Ethiopia  Sub-Saharan Africa    Low income          IDA

# %%
df2.tail()
# Out:
#        Unnamed: 0  Year        value    indicator Country Code Country Name  \
# 30825       30825  2017  207906210.0  SP.POP.TOTL          PAK     Pakistan
# 30826       30826  2018  212228288.0  SP.POP.TOTL          PAK     Pakistan
# 30827       30827  2019  216565317.0  SP.POP.TOTL          PAK     Pakistan
# 30828       30828  2020  220892331.0  SP.POP.TOTL          PAK     Pakistan
# 30829       30829  2021  225199929.0  SP.POP.TOTL          PAK     Pakistan
#
#            Region         Income Group Lending Type
# 30825  South Asia  Lower middle income        Blend
# 30826  South Asia  Lower middle income        Blend
# 30827  South Asia  Lower middle income        Blend
# 30828  South Asia  Lower middle income        Blend
# 30829  South Asia  Lower middle income        Blend

# %%
df3 = df2.query('indicator == "SP.POP.TOTL" and Year == 2021')   # querying the data frame to get data of that specific indicator and year

df3
# Out:
#        Unnamed: 0  Year         value    indicator Country Code Country Name  \
# 25562       25562  2021  1.178762e+08  SP.POP.TOTL          ETH     Ethiopia
# 27112       27112  2021  1.393409e+09  SP.POP.TOTL          IND        India
# 30829       30829  2021  2.251999e+08  SP.POP.TOTL          PAK     Pakistan
#
#                     Region         Income Group Lending Type
# 25562  Sub-Saharan Africa            Low income          IDA
# 27112           South Asia  Lower middle income         IBRD
# 30829           South Asia  Lower middle income        Blend

# %% [markdown]
# ### Comparing one year (picking the latest year) using bar chart

# %%
fig = px.bar(
    df3, 
    x="Country Name", 
    y="value", 
    title="2021 Population of USA, China, and India", 
    color="Country Name", 
    template="plotly_dark"
)

fig.update_layout(showlegend=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="082f84d5-a4dc-48f8-8458-3b4c04468723" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("082f84d5-a4dc-48f8-8458-3b4c04468723")) {                    Plotly.newPlot(                        "082f84d5-a4dc-48f8-8458-3b4c04468723",                        [{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Ethiopia","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Ethiopia","offsetgroup":"Ethiopia","orientation":"v","showlegend":true,"textposition":"auto","x":["Ethiopia"],"xaxis":"x","y":[117876226.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>value=%{y}<extra></extra>","legendgroup":"India","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"India","offsetgroup":"India","orientation":"v","showlegend":true,"textposition":"auto","x":["India"],"xaxis":"x","y":[1393409033.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Pakistan","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Pakistan","offsetgroup":"Pakistan","orientation":"v","showlegend":true,"textposition":"auto","x":["Pakistan"],"xaxis":"x","y":[225199929.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111 ...

# %% [markdown]
# ### Comparing one year (picking the latest year) using pie chart

# %%
fig = px.pie(
    df3, 
    names="Country Name", 
    values="value", 
    title="2021 Population of USA, China, and India", 
    color="Country Name", 
    template="plotly_dark"
)

fig.update_layout(showlegend=False)

fig.update_traces(textposition='inside', textinfo='label+percent+value')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="7ac33066-7601-4e4a-8811-12b7b005867a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7ac33066-7601-4e4a-8811-12b7b005867a")) {                    Plotly.newPlot(                        "7ac33066-7601-4e4a-8811-12b7b005867a",                        [{"customdata":[["Ethiopia"],["India"],["Pakistan"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Country Name=%{customdata[0]}<br>value=%{value}<extra></extra>","labels":["Ethiopia","India","Pakistan"],"legendgroup":"","marker":{"colors":["#636efa","#EF553B","#00cc96"]},"name":"","showlegend":true,"values":[117876226.0,1393409033.0,225199929.0],"type":"pie","textinfo":"label+percent+value","textposition":"inside"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter ...

# %% [markdown]
# ### Comparing all years using line chart

# %%
df4 = df2.query('indicator == "SP.POP.TOTL"')

df4.head()
# Out:
#        Unnamed: 0  Year       value    indicator Country Code Country Name  \
# 25501       25501  1960  22151284.0  SP.POP.TOTL          ETH     Ethiopia
# 25502       25502  1961  22671193.0  SP.POP.TOTL          ETH     Ethiopia
# 25503       25503  1962  23221385.0  SP.POP.TOTL          ETH     Ethiopia
# 25504       25504  1963  23798418.0  SP.POP.TOTL          ETH     Ethiopia
# 25505       25505  1964  24397010.0  SP.POP.TOTL          ETH     Ethiopia
#
#                     Region Income Group Lending Type
# 25501  Sub-Saharan Africa    Low income          IDA
# 25502  Sub-Saharan Africa    Low income          IDA
# 25503  Sub-Saharan Africa    Low income          IDA
# 25504  Sub-Saharan Africa    Low income          IDA
# 25505  Sub-Saharan Africa    Low income          IDA

# %%
fig = px.line(
    df4,
    x="Year",
    y="value", 
    title="Population of USA, China, and India over time", 
    color="Country Name", 
    template="plotly_dark"
)

fig.update_layout(showlegend=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4c979a7b-82e1-41de-b4c9-b650dffdfec5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4c979a7b-82e1-41de-b4c9-b650dffdfec5")) {                    Plotly.newPlot(                        "4c979a7b-82e1-41de-b4c9-b650dffdfec5",                        [{"hovertemplate":"Country Name=Ethiopia<br>Year=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Ethiopia","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Ethiopia","orientation":"v","showlegend":true,"x":[1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[22151284.0,22671193.0,23221385.0,23798418.0,24397010.0,25013634.0,25641040.0,26280135.0,26944386.0,27652715.0,28415080.0,29248650.0,30140799.0,31036670.0,31861353.0,32566855.0,33128151.0,33577240.0,33993301.0,34487806.0,35141703.0,35984531.0,36995246.0,38142679.0,39374346.0,40652146.0,41965696.0,43329238.0,44757205.0,46272308.0,47887864.0,49609976.0,51423591.0,53295556.0,55180993.0,57047906.0,58883531.0,60697443.0,62507724.0,64343008.0,66224809.0,68159422.0,70142090.0,72170581.0,74239508.0,76346310.0,78489205.0,80674343.0,82916236.0,85233923.0,87639962.0,90139928.0,92726982.0,95385793.0,98094264.0,100835453.0,103603461.0,106399926.0,109224410.0,112078727.0,114963583.0,117876226.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=India<br>Year=%{x}<br>value=%{y}<extra></extra>","legendgroup":"India","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"India","orientation":"v","showlegend":true,"x":[1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[450547675.0,459642166.0,469077191.0,478825602.0,488848139.0,499123328.0,509631509.0,520400577.0,531513834.0,543084333.0,555189797.0,567868021.0,581087255.0,594770136.0,608802595.0,623102900.0,637630085.0,652408766.0,667499815.0,682995348.0,698952837.0,715384997.0,732239498.0,749428958.0,766833411.0,784360012.0,801975250.0,819682095.0,837468938.0,855334675.0,873277799.0,891273202.0,909307018.0,927403866.0,945601828.0,963922586.0,982365248.0,1000900028.0,1019483586.0,1038058154.0,1056575548.0,1075000094.0,1093317187.0,1111523146.0,1129623466.0,1147609924.0,1165486291.0,1183209471.0,1200669762.0,1217726217.0,1234281163.0,1250287939.0,1265780243.0,1280842119.0,1295600768.0,1310152392.0,1324517250.0,1338676779.0,1352642283.0,1366417756.0,1380004385.0,1393409033.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=Pakistan<br>Year=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Pakistan","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Pakistan","orientation":"v","showlegend":true,"x":[1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[44988690.0,46065229.0,47198886.0,48387293.0,49627623.0,50917975.0,52260183.0,53655783.0,55102690.0,56598148.0,58142062.0,59734479.0,61381982.0,63099404.0,64905996.0,66816875.0,68834324.0,70958168.0,7 ...

# %% [markdown]
# ### Comparing all regions to see how they differ in the indicator
# - Comparing one year (picking the latest year) using bar chart, pie chart
# - Comparing all years using line chart
# - Note one: For population, you compare total, for the other three indicators, you compare the average.
# - Note two: you need to use groupby method to get the sum or mean of a column for a group (here the group is region)

# %% [markdown]
# #### Manipulating the data to get desired set of data

# %%
df
df_1 = df.query('indicator == "SP.POP.TOTL" and Year == 2021')
df_1
# Out:
#        Unnamed: 0  Year       value    indicator Country Code  \
# 21604       21604  2021  39835428.0  SP.POP.TOTL          AFG
# 21666       21666  2021   2811666.0  SP.POP.TOTL          ALB
# 21728       21728  2021  44616626.0  SP.POP.TOTL          DZA
# 21790       21790  2021     55103.0  SP.POP.TOTL          ASM
# 21852       21852  2021     77354.0  SP.POP.TOTL          AND
# ...           ...   ...         ...          ...          ...
# 34735       34735  2021    105870.0  SP.POP.TOTL          VIR
# 34767       34767  2021   4922749.0  SP.POP.TOTL          PSE
# 34829       34829  2021  30490639.0  SP.POP.TOTL          YEM
# 34891       34891  2021  18920657.0  SP.POP.TOTL          ZMB
# 34953       34953  2021  15092171.0  SP.POP.TOTL          ZWE
#
#                 Country Name                      Region         Income Group  \
# 21604            Afghanistan                  South Asia           Low income
# 21666                Albania       Europe & Central Asia  Upper middle income
# 21728                Algeria  Middle East & North Africa  Lower middle income
# 21790         American Samoa         East Asia & Pacific  Upper middle income
# 21852                Andorra       Europe & Central Asia          High income
# ...                      ...                         ...                  ...
# 34735  Virgin Islands (U.S.)  Latin America & Caribbean           High income
# 34767     West Bank and Gaza  Middle East & North Africa  Lower middle income
# 34829            Yemen, Rep.  Middle East & North Africa           Low income
# 34891                 Zambia         Sub-Saharan Africa            Low income
# 34953               Zimbabwe         Sub-Saharan Africa   Lower middle income
#
#          Lending Type
# 21604             IDA
# 21666            IBRD
# 21728            IBRD
# 21790  Not classified
# 21852  Not classified
# ...               ...
# 34735  Not classified
# 34767  Not classified
# 34829             IDA
# 34891             IDA
# 34953           Blend
#
# [216 rows x 9 columns]

# %%
df_2 = df_1[["Year", "value", "Region"]]

# grouping the data frame together and calculating the sum of population and resetting the index

df_3 = df_2.groupby(["Region","Year"]).sum("value").reset_index()   
df_3
# Out:
#                        Region  Year         value
# 0         East Asia & Pacific  2021  2.345135e+09
# 1       Europe & Central Asia  2021  9.237537e+08
# 2  Latin America & Caribbean   2021  6.580892e+08
# 3  Middle East & North Africa  2021  4.724950e+08
# 4               North America  2021  3.702037e+08
# 5                  South Asia  2021  1.877902e+09
# 6         Sub-Saharan Africa   2021  1.161963e+09

# %% [markdown]
# ### Comparing one year (picking the latest year) using bar chart

# %%
fig = px.bar(
    df_3, 
    x="Region", 
    y="value", 
    title="Population Across the World in 2021", 
    color="Region", 
    #barmode = "group"
    template = "plotly_dark"
)

fig.update_layout(showlegend=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="83f8003c-e069-4db6-ac58-18dec6097b86" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("83f8003c-e069-4db6-ac58-18dec6097b86")) {                    Plotly.newPlot(                        "83f8003c-e069-4db6-ac58-18dec6097b86",                        [{"alignmentgroup":"True","hovertemplate":"Region=%{x}<br>value=%{y}<extra></extra>","legendgroup":"East Asia & Pacific","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"East Asia & Pacific","offsetgroup":"East Asia & Pacific","orientation":"v","showlegend":true,"textposition":"auto","x":["East Asia & Pacific"],"xaxis":"x","y":[2345135350.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Europe & Central Asia","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Europe & Central Asia","offsetgroup":"Europe & Central Asia","orientation":"v","showlegend":true,"textposition":"auto","x":["Europe & Central Asia"],"xaxis":"x","y":[923753699.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Latin America & Caribbean ","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Latin America & Caribbean ","offsetgroup":"Latin America & Caribbean ","orientation":"v","showlegend":true,"textposition":"auto","x":["Latin America & Caribbean "],"xaxis":"x","y":[658089208.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Middle East & North Africa","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Middle East & North Africa","offsetgroup":"Middle East & North Africa","orientation":"v","showlegend":true,"textposition":"auto","x":["Middle East & North Africa"],"xaxis":"x","y":[472494995.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}<br>value=%{y}<extra></extra>","legendgroup":"North America","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"North America","offsetgroup":"North America","orientation":"v","showlegend":true,"textposition":"auto","x":["North America"],"xaxis":"x","y":[370203720.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}<br>value=%{y}<extra></extra>","legendgroup":"South Asia","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"South Asia","offsetgroup":"South Asia","orientation":"v","showlegend":true,"textposition":"auto","x":["South Asia"],"xaxis":"x","y":[1877902324.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Sub-Saharan Africa ","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Sub-Saharan Africa ","offsetgroup":"Sub-Saharan Africa ","orientation":"v","showlegend":true,"textposition":"auto","x":["Sub-Saharan Africa "],"xaxis":"x","y":[1161962525.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{ ...

# %% [markdown]
# ### Comparing one year (picking the latest year) using pie chart

# %%
fig = px.pie(
    df_3, 
    names="Region", 
    values="value", 
    title="Population Across the world in 2021", 
    color="Region", 
    template="plotly_dark"
)

fig.update_layout(showlegend=False)

fig.update_traces(textposition='inside', textinfo='label+percent+value')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="fcf9b395-ea8c-416e-81e4-afab7b2b8191" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fcf9b395-ea8c-416e-81e4-afab7b2b8191")) {                    Plotly.newPlot(                        "fcf9b395-ea8c-416e-81e4-afab7b2b8191",                        [{"customdata":[["East Asia & Pacific"],["Europe & Central Asia"],["Latin America & Caribbean "],["Middle East & North Africa"],["North America"],["South Asia"],["Sub-Saharan Africa "]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Region=%{customdata[0]}<br>value=%{value}<extra></extra>","labels":["East Asia & Pacific","Europe & Central Asia","Latin America & Caribbean ","Middle East & North Africa","North America","South Asia","Sub-Saharan Africa "],"legendgroup":"","marker":{"colors":["#636efa","#EF553B","#00cc96","#ab63fa","#FFA15A","#19d3f3","#FF6692"]},"name":"","showlegend":true,"values":[2345135350.0,923753699.0,658089208.0,472494995.0,370203720.0,1877902324.0,1161962525.0],"type":"pie","textinfo":"label+percent+value","textposition":"inside"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0," ...

# %% [markdown]
# ### Manipulating the data frame to get the desired set of data to plot line chart.

# %%
df_4 = df.query('indicator == "SP.POP.TOTL"')
df_4
# Out:
#        Unnamed: 0  Year       value    indicator Country Code Country Name  \
# 21543       21543  1960   8996967.0  SP.POP.TOTL          AFG  Afghanistan
# 21544       21544  1961   9169406.0  SP.POP.TOTL          AFG  Afghanistan
# 21545       21545  1962   9351442.0  SP.POP.TOTL          AFG  Afghanistan
# 21546       21546  1963   9543200.0  SP.POP.TOTL          AFG  Afghanistan
# 21547       21547  1964   9744772.0  SP.POP.TOTL          AFG  Afghanistan
# ...           ...   ...         ...          ...          ...          ...
# 34949       34949  2017  14236599.0  SP.POP.TOTL          ZWE     Zimbabwe
# 34950       34950  2018  14438812.0  SP.POP.TOTL          ZWE     Zimbabwe
# 34951       34951  2019  14645473.0  SP.POP.TOTL          ZWE     Zimbabwe
# 34952       34952  2020  14862927.0  SP.POP.TOTL          ZWE     Zimbabwe
# 34953       34953  2021  15092171.0  SP.POP.TOTL          ZWE     Zimbabwe
#
#                     Region         Income Group Lending Type
# 21543           South Asia           Low income          IDA
# 21544           South Asia           Low income          IDA
# 21545           South Asia           Low income          IDA
# 21546           South Asia           Low income          IDA
# 21547           South Asia           Low income          IDA
# ...                    ...                  ...          ...
# 34949  Sub-Saharan Africa   Lower middle income        Blend
# 34950  Sub-Saharan Africa   Lower middle income        Blend
# 34951  Sub-Saharan Africa   Lower middle income        Blend
# 34952  Sub-Saharan Africa   Lower middle income        Blend
# 34953  Sub-Saharan Africa   Lower middle income        Blend
#
# [13411 rows x 9 columns]

# %%
df_5 = df_4[["Year", "value", "Region"]]
df_5
# Out:
#        Year       value               Region
# 21543  1960   8996967.0           South Asia
# 21544  1961   9169406.0           South Asia
# 21545  1962   9351442.0           South Asia
# 21546  1963   9543200.0           South Asia
# 21547  1964   9744772.0           South Asia
# ...     ...         ...                  ...
# 34949  2017  14236599.0  Sub-Saharan Africa
# 34950  2018  14438812.0  Sub-Saharan Africa
# 34951  2019  14645473.0  Sub-Saharan Africa
# 34952  2020  14862927.0  Sub-Saharan Africa
# 34953  2021  15092171.0  Sub-Saharan Africa
#
# [13411 rows x 3 columns]

# %%
df_6 = df_5.groupby(["Region","Year"]).sum(["value"]).reset_index()
df_6.sample(10)
# Out:
#                          Region  Year         value
# 15          East Asia & Pacific  1975  1.426918e+09
# 388         Sub-Saharan Africa   1976  3.420189e+08
# 131  Latin America & Caribbean   1967  2.651879e+08
# 409         Sub-Saharan Africa   1997  6.150543e+08
# 112       Europe & Central Asia  2010  8.879043e+08
# 326                  South Asia  1976  8.192925e+08
# 51          East Asia & Pacific  2011  2.199397e+09
# 254               North America  1966  2.166590e+08
# 77        Europe & Central Asia  1975  7.666256e+08
# 56          East Asia & Pacific  2016  2.284199e+09

# %% [markdown]
# ### Comparing all years using line chart

# %%
fig = px.line(
    df_6,
    x="Year",
    y="value", 
    title="Growth of Population Across Various Regions", 
    color="Region", 
    template="plotly_dark"
)

fig.update_layout(showlegend=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a1f51b59-d60d-43c6-99a0-c2423b1f1271" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a1f51b59-d60d-43c6-99a0-c2423b1f1271")) {                    Plotly.newPlot(                        "a1f51b59-d60d-43c6-99a0-c2423b1f1271",                        [{"hovertemplate":"Region=East Asia & Pacific<br>Year=%{x}<br>value=%{y}<extra></extra>","legendgroup":"East Asia & Pacific","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"East Asia & Pacific","orientation":"v","showlegend":true,"x":[1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[1030971854.0,1032584288.0,1046667371.0,1072042214.0,1097049797.0,1123110704.0,1152593187.0,1181214550.0,1210933821.0,1242448013.0,1274871399.0,1309171954.0,1340715058.0,1371312193.0,1400473157.0,1426917696.0,1451172534.0,1473728221.0,1496200846.0,1519083033.0,1541515841.0,1564773439.0,1590355395.0,1615935307.0,1640266860.0,1665186778.0,1691568632.0,1719432813.0,1747555306.0,1775056912.0,1801855611.0,1827761841.0,1851991427.0,1875316687.0,1898499439.0,1921206384.0,1943722394.0,1965715373.0,1986871715.0,2006642337.0,2025467562.0,2043572497.0,2060728598.0,2077048228.0,2092818375.0,2108424288.0,2123929469.0,2138883614.0,2154124876.0,2168990055.0,2183746241.0,2199397246.0,2217050964.0,2234560278.0,2251683949.0,2268042163.0,2284198865.0,2300568081.0,2314911113.0,2327536911.0,2337933859.0,2345135350.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Europe & Central Asia<br>Year=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Europe & Central Asia","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Europe & Central Asia","orientation":"v","showlegend":true,"x":[1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[666753356.0,674450666.0,682397828.0,690411692.0,698355574.0,706070460.0,712830312.0,719406020.0,725725300.0,731903738.0,737524825.0,743140589.0,749283635.0,755259488.0,761029417.0,766625562.0,772129341.0,777422111.0,782653852.0,787910910.0,793299463.0,798559755.0,803342746.0,807903880.0,812662217.0,817497806.0,822470047.0,827505281.0,832553390.0,837438555.0,841536999.0,845399658.0,848878429.0,851973886.0,854082087.0,855490982.0,856856802.0,858163120.0,859296518.0,860311870.0,861270071.0,862339994.0,863908064.0,866189044.0,868783653.0,871433207.0,874134287.0,877278821.0,880911644.0,884448855.0,887904313.0,890136603.0,893755804.0,898022522.0,902367876.0,906669764.0,910870489.0,914608311.0,918031055.0,920807612.0,922976036.0,923753699.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Latin America & Caribbean <br>Year=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Latin America & Caribbean ","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Latin America & Caribbean ","orientation":"v","showlegend":true,"x":[1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis" ...

# %% [markdown]
# ### Using all countries, and picking a year 2020, make a scatter plot with x being GDP per Capita and y being Life Expentancy. This plot will tell you the relationship between wealth and health.

# %% [markdown]
# #### Manipulating the data frame to get the desired set of data to plot the scatter plot

# %%
df["indicator"].unique()
# Out:
# array(['NY.GDP.PCAP.PP.CD', 'SH.STA.SUIC.P5', 'SP.DYN.LE00.IN',
#        'SP.POP.TOTL'], dtype=object)

# %%
my_indicators = ["SP.DYN.LE00.IN", "NY.GDP.PCAP.PP.CD"]

df_7 = df[df["indicator"].isin(my_indicators)]

df_7.shape
# Out:
# (17883, 9)

# %%
df_8 = df_7.query('Year == 2020')
df_8
# Out:
#        Unnamed: 0  Year         value          indicator Country Code  \
# 18             18  2020   2078.479082  NY.GDP.PCAP.PP.CD          AFG
# 49             49  2020  13632.186537  NY.GDP.PCAP.PP.CD          ALB
# 81             81  2020  11323.312219  NY.GDP.PCAP.PP.CD          DZA
# 113           113  2020   6478.332182  NY.GDP.PCAP.PP.CD          AGO
# 145           145  2020  18240.380406  NY.GDP.PCAP.PP.CD          ATG
# ...           ...   ...           ...                ...          ...
# 21328       21328  2020     79.819512     SP.DYN.LE00.IN          VIR
# 21359       21359  2020     74.213000     SP.DYN.LE00.IN          PSE
# 21420       21420  2020     66.181000     SP.DYN.LE00.IN          YEM
# 21481       21481  2020     64.194000     SP.DYN.LE00.IN          ZMB
# 21542       21542  2020     61.738000     SP.DYN.LE00.IN          ZWE
#
#                 Country Name                      Region         Income Group  \
# 18               Afghanistan                  South Asia           Low income
# 49                   Albania       Europe & Central Asia  Upper middle income
# 81                   Algeria  Middle East & North Africa  Lower middle income
# 113                   Angola         Sub-Saharan Africa   Lower middle income
# 145      Antigua and Barbuda  Latin America & Caribbean           High income
# ...                      ...                         ...                  ...
# 21328  Virgin Islands (U.S.)  Latin America & Caribbean           High income
# 21359     West Bank and Gaza  Middle East & North Africa  Lower middle income
# 21420            Yemen, Rep.  Middle East & North Africa           Low income
# 21481                 Zambia         Sub-Saharan Africa            Low income
# 21542               Zimbabwe         Sub-Saharan Africa   Lower middle income
#
#          Lending Type
# 18                IDA
# 49               IBRD
# 81               IBRD
# 113              IBRD
# 145              IBRD
# ...               ...
# 21328  Not classified
# 21359  Not classified
# 21420             IDA
# 21481             IDA
# 21542           Blend
#
# [391 rows x 9 columns]

# %%
df_9 = df_8[["Year",	"value",	"indicator",	"Country Code",	"Country Name"]]
          
df_9.sample(5)
# Out:
#        Year         value          indicator Country Code  \
# 19986  2020     83.100000     SP.DYN.LE00.IN          CHE
# 17671  2020     55.018000     SP.DYN.LE00.IN          NGA
# 464    2020  14045.772832  NY.GDP.PCAP.PP.CD          BRB
# 715    2020  15598.430339  NY.GDP.PCAP.PP.CD          BIH
# 779    2020  14834.193702  NY.GDP.PCAP.PP.CD          BRA
#
#                  Country Name
# 19986             Switzerland
# 17671                 Nigeria
# 464                  Barbados
# 715    Bosnia and Herzegovina
# 779                    Brazil

# %%
# Converting the data frame to a pivot table to make the plotting easy
df_10 = pd.pivot_table(df_9, values = 'value', index=['Country Code', 'Country Name','Year'], columns = 'indicator').reset_index()

df_10.sample(10)
# Out:
# indicator Country Code         Country Name  Year  NY.GDP.PCAP.PP.CD  \
# 100                KNA  St. Kitts and Nevis  2020       25639.239599
# 150                POL               Poland  2020       34286.985085
# 207                ZMB               Zambia  2020        3457.328102
# 125                MMR              Myanmar  2020        5123.407709
# 60                 FIN              Finland  2020       50937.160754
# 45                 CYM       Cayman Islands  2020       72481.013856
# 55                 EGY     Egypt, Arab Rep.  2020       12605.975737
# 199                VEN        Venezuela, RB  2020                NaN
# 185                TKM         Turkmenistan  2020                NaN
# 58                 EST              Estonia  2020       37645.221361
#
# indicator  SP.DYN.LE00.IN
# 100                   NaN
# 150             76.600000
# 207             64.194000
# 125             67.363000
# 60              82.131707
# 45                    NaN
# 55              72.150000
# 199             72.066000
# 185             68.313000
# 58              78.346341

# %%
df_10.dropna(inplace=True)

df_10.sample(10)
# Out:
# indicator Country Code Country Name  Year  NY.GDP.PCAP.PP.CD  SP.DYN.LE00.IN
# 125                MMR      Myanmar  2020        5123.407709       67.363000
# 83                 HUN      Hungary  2020       33274.347656       75.617073
# 109                LKA    Sri Lanka  2020       13226.730058       77.144000
# 27                 BTN       Bhutan  2020       11129.308455       72.080000
# 138                NLD  Netherlands  2020       59266.908581       81.409756
# 204                XKX       Kosovo  2020       11292.862651       71.087805
# 98                 KHM     Cambodia  2020        4423.474631       70.054000
# 21                 BLZ       Belize  2020        6165.849669       74.754000
# 102                KWT       Kuwait  2020       47303.129853       75.586000
# 48                 DEU      Germany  2020       54844.545973       80.941463

# %% [markdown]
# ### Scatter Plot showing Wealth vs Health

# %%
fig = px.scatter(
    df_10,
    x="NY.GDP.PCAP.PP.CD",
    y="SP.DYN.LE00.IN", 
    title="Wealth vs Health", 
    color="Country Name", 
    template="plotly_dark"
)

fig.update_layout(showlegend=True)
fig.update_layout(
    xaxis_title="GDP per Capita",
    yaxis_title="Life Expectancy",)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="82f8a62c-924e-4ddc-a05c-81f6d83da207" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("82f8a62c-924e-4ddc-a05c-81f6d83da207")) {                    Plotly.newPlot(                        "82f8a62c-924e-4ddc-a05c-81f6d83da207",                        [{"hovertemplate":"Country Name=Aruba<br>NY.GDP.PCAP.PP.CD=%{x}<br>SP.DYN.LE00.IN=%{y}<extra></extra>","legendgroup":"Aruba","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Aruba","orientation":"v","showlegend":true,"x":[31182.8338812015],"xaxis":"x","y":[76.434],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=Afghanistan<br>NY.GDP.PCAP.PP.CD=%{x}<br>SP.DYN.LE00.IN=%{y}<extra></extra>","legendgroup":"Afghanistan","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Afghanistan","orientation":"v","showlegend":true,"x":[2078.479081826],"xaxis":"x","y":[65.173],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=Angola<br>NY.GDP.PCAP.PP.CD=%{x}<br>SP.DYN.LE00.IN=%{y}<extra></extra>","legendgroup":"Angola","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Angola","orientation":"v","showlegend":true,"x":[6478.3321819683],"xaxis":"x","y":[61.487],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=Albania<br>NY.GDP.PCAP.PP.CD=%{x}<br>SP.DYN.LE00.IN=%{y}<extra></extra>","legendgroup":"Albania","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"Albania","orientation":"v","showlegend":true,"x":[13632.1865366302],"xaxis":"x","y":[78.686],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=United Arab Emirates<br>NY.GDP.PCAP.PP.CD=%{x}<br>SP.DYN.LE00.IN=%{y}<extra></extra>","legendgroup":"United Arab Emirates","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"United Arab Emirates","orientation":"v","showlegend":true,"x":[66766.0539321336],"xaxis":"x","y":[78.12],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=Argentina<br>NY.GDP.PCAP.PP.CD=%{x}<br>SP.DYN.LE00.IN=%{y}<extra></extra>","legendgroup":"Argentina","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"Argentina","orientation":"v","showlegend":true,"x":[20769.0323781598],"xaxis":"x","y":[76.813],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=Armenia<br>NY.GDP.PCAP.PP.CD=%{x}<br>SP.DYN.LE00.IN=%{y}<extra></extra>","legendgroup":"Armenia","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"Armenia","orientation":"v","showlegend":true,"x":[13311.0281362153],"xaxis":"x","y":[75.224],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=Antigua and Barbuda<br>NY.GDP.PCAP.PP.CD=%{x}<br>SP.DYN.LE00.IN=%{y}<extra></extra>","legendgroup":"Antigua and Barbuda","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"Antigua and Barbuda","orientation":"v","showlegend":true,"x":[18240.3804056479],"xaxis":"x","y":[77.146],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=Australia<br>NY.GDP.PCAP.PP.CD=%{x}<br>SP.DYN.LE00.IN=%{y}<extra></extra>","legendgroup":"Australia","marker":{"color":"#FF97FF","symbol":"circle"},"mode":"markers","name":"Australia","orientation":"v","showlegend":true,"x":[53316.8854335814],"xaxis":"x","y":[83.2],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=Austria<br>NY.GDP.PCAP.PP.CD=%{x}<br>SP.DYN.LE00.IN=%{y}<extra></extra>","legendgroup":"Austria","marker":{"color":"#FECB52","symbol":"circle"},"mode":"markers","name":"Austria","orientation":"v","showlegend":true,"x":[55685.9702933361],"xaxis":"x","y":[81.1926829268],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=Azerbaijan<br>NY.GDP.PCAP.PP.CD=%{x}<br>SP.DYN.LE00.IN=%{y}<extra></extra>","legendgroup":"Azerbaijan ...
